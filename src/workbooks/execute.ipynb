# %%
import sys
from asyncio import run
sys.path.insert(0, "/home/jovyan/work/src")
sys.path.insert(0, "/home/jovyan/work/src/graphing")

import graph_input

await graph_input.main()
# Out:
# [2021-05-30 08:45:05.678][INFO][Model 1] ##############################################################
# [2021-05-30 08:45:05.678][INFO][Model 1] #       Datascience in Techno-Socio-Economic Systems         #
# [2021-05-30 08:45:05.678][INFO][Model 1] #                                                            #
# [2021-05-30 08:45:05.678][INFO][Model 1] #                 Forecasting the PM10 value                 #
# [2021-05-30 08:45:05.678][INFO][Model 1] ##############################################################
# [2021-05-30 08:45:05.679][INFO][Model 1] start predicting new time
# [2021-05-30 08:45:07.877][INFO][Imputer] Imputing missing values...                                 Done in 00:00:00.00s
# [2021-05-30 08:45:07.884][INFO][Moving Average] Computing moving average...                         Done in 00:00:00.01s
