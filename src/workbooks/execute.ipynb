# %%
import sys
from asyncio import run
sys.path.insert(0, "/home/jovyan/work/src")
sys.path.insert(0, "/home/jovyan/work/src/graphing")

import graph_input

await graph_input.main()
# Out:
# [2021-05-30 10:42:57.015][INFO][Model 1] ##############################################################
# [2021-05-30 10:42:57.015][INFO][Model 1] #       Datascience in Techno-Socio-Economic Systems         #
# [2021-05-30 10:42:57.015][INFO][Model 1] #                                                            #
# [2021-05-30 10:42:57.015][INFO][Model 1] #                 Forecasting the PM10 value                 #
# [2021-05-30 10:42:57.015][INFO][Model 1] ##############################################################
# [2021-05-30 10:42:57.016][INFO][Model 1] start predicting new time
# [2021-05-30 10:42:57.771][INFO][Imputer] Imputing missing values...                                 Done in 00:00:00.00s
# [2021-05-30 10:42:57.777][INFO][Moving Average] Computing moving average...                         Done in 00:00:00.01s

# %%
import sys
from asyncio import run
sys.path.insert(0, "/home/jovyan/work/src")
sys.path.insert(0, "/home/jovyan/work/src/graphing")

import graph_result_to_forecasts

await graph_result_to_forecasts.main()
# Out:
# [2021-05-30 11:33:05.182][INFO][Model 1] ##############################################################
# [2021-05-30 11:33:05.182][INFO][Model 1] #       Datascience in Techno-Socio-Economic Systems         #
# [2021-05-30 11:33:05.182][INFO][Model 1] #                                                            #
# [2021-05-30 11:33:05.182][INFO][Model 1] #                 Forecasting the PM10 value                 #
# [2021-05-30 11:33:05.182][INFO][Model 1] ##############################################################
# [2021-05-30 11:33:05.182][INFO][Model 1] Loading dataset...
# [2021-05-30 11:33:05.182][INFO][hist data adapter 'zurich_adapter'] Loading sqlite...
# [2021-05-30 11:33:05.799][INFO][hist data adapter 'zurich_adapter'] done
# [2021-05-30 11:33:05.800][INFO][Model 1] Done in 00:00:00.62s
# [2021-05-30 11:33:05.800][INFO][Model 1] Loading dataset...
# [2021-05-30 11:33:05.802][INFO][Model 1] Done in 00:00:00.00s
# ...
